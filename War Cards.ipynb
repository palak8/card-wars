# %%
import random

# %%
suits=('Hearts','Diamonds','Spades','Clubs')
ranks=('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values={'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':11,'Queen':12,
        'King':13,'Ace':14}

# %%
class Cards:
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value=values[rank]
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
  
    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                create_card=Cards(suit,rank)
                
                self.all_cards.append(create_card)
    
    def shuffle(self):
        
        random.shuffle(self.all_cards)
       
    def remove_one(self):
        
        return self.all_cards.pop()

# %%
class Player:
    
    def __init__(self,name):
        self.name=name
        self.all_cards = []
        
    def remove_one(self):
        
        return self.all_cards.pop()
    
    def add_card(self,new_card):
        
        if type(new_card)==type([]):
            self.all_cards.extend(new_card)
        else:
            self.all_cards.append(new_card)
            
    def __str__(self):
        
        return f'Player {self.name} has {len(self.all_cards) } cards. '

# %%
player1=Player("One")
player2=Player("Two")

new_deck=Deck()
new_deck.shuffle()

for x in range(26):
    player1.add_card(new_deck.remove_one())
    player2.add_card(new_deck.remove_one())

# %%
start=True

round_num=0

while start:
    
    round_num += 1
    print(f"Round {round_num}")
    
    if len((player1.all_cards))==0:
        print("Player Two Wins!!")
        start=False
        break
    if len((player2.all_cards))==0:
        print("Player One Wins!!")
        start=False
        break
    
    ones_cards= []
    ones_cards.append(player1.all_cards.pop())
    
    
    
    twos_cards= []
    twos_cards.append(player2.all_cards.pop())
    
    print('P1 (' + str(len(player1.all_cards)) + ') ' + ones_cards[-1].rank +
          ' <-> ' + 
          twos_cards[-1].rank + '('+ str(len(player2.all_cards)) + ') P2')
    war=True
    
    while war:
        
        if (ones_cards[-1].value) > (twos_cards[-1].value) :
            
            player1.add_card(ones_cards)
            player1.add_card(twos_cards)
            
            war=False
        
        elif (ones_cards[-1].value) < (twos_cards[-1].value) :
            
            player2.add_card(ones_cards)
            player2.add_card(twos_cards)
            
            war=False
        
        else:
            
            print("!!WAR!!")
            
            if len(player1.all_cards) < 3:
                print("Player 1 is unable to declare war.")
                print("Player 2 wins.")
                start=False
                break
                
            elif len(player2.all_cards) < 3:
                print("Player 2 is unable to declare war.")
                print("Player 1 wins.")
                start=False
                break
                
            else:
                
                for x in range(3):
                    ones_cards.append(player1.remove_one())
                    twos_cards.append(player2.remove_one())
                    print('P1 (' + str(len(player1.all_cards)) + ') ' + ones_cards[-1].rank +' <-> ' +  twos_cards[-1].rank + '('+ str(len(player2.all_cards)) + ') P2')
# Out:
# Round 1
# P1 (25) Six <-> Ace(25) P2
# Round 2
# P1 (24) Jack <-> Ace(26) P2
# Round 3
# P1 (23) Eight <-> Ace(27) P2
# Round 4
# P1 (22) Ace <-> Ace(28) P2
# !!WAR!!
# P1 (21) Five <-> Eight(27) P2
# P1 (20) Queen <-> Jack(26) P2
# P1 (19) Jack <-> Six(25) P2
# Round 5
# P1 (26) Six <-> Five(24) P2
# Round 6
# P1 (27) Five <-> Nine(23) P2
# Round 7
# P1 (26) Six <-> Nine(24) P2
# Round 8
# P1 (25) Jack <-> Nine(25) P2
# Round 9
# P1 (26) Nine <-> Six(24) P2
# Round 10
# P1 (27) Six <-> Five(23) P2
# Round 11
# P1 (28) Five <-> Six(22) P2
# Round 12
# P1 (27) Six <-> Six(23) P2
# !!WAR!!
# P1 (26) Nine <-> Five(22) P2
# P1 (25) Jack <-> Seven(21) P2
# P1 (24) Eight <-> Ten(20) P2
# Round 13
# P1 (23) Ace <-> Ten(27) P2
# Round 14
# P1 (24) Ten <-> Seven(26) P2
# Round 15
# P1 (25) Seven <-> Five(25) P2
# Round 16
# P1 (26) Five <-> Six(24) P2
# Round 17
# P1 (25) Seven <-> Six(25) P2
# Round 18
# P1 (26) Six <-> Five(24) P2
# Round 19
# P1 (27) Five <-> Eight(23) P2
# Round 20
# P1 (26) Six <-> Eight(24) P2
# Round 21
# P1 (25) Seven <-> Eight(25) P2
# Round 22
# P1 (24) Ten <-> Eight(26) P2
# Round 23
# P1 (25) Eight <-> Seven(25) P2
# Round 24
# P1 (26) Seven <-> Six(24) P2
# Round 25
# P1 (27) Six <-> Five(23) P2
# Round 26
# P1 (28) Five <-> Jack(22) P2
# Round 27
# P1 (27) Six <-> Jack(23) P2
# Round 28
# P1 (26) Seven <-> Jack(24) P2
# Round 29
# P1 (25) Eight <-> Jack(25) P2
# Round 30
# P1 (24) Ten <-> Jack(26) P2
# Round 31
# P1 (23) Ace <-> Jack(27) P2
# Round 32
# P1 (24) Jack <-> Ten(26) P2
# Round 33
# P1 (25) Ten <-> Eight(25) P2
# Round 34
# P1 (26) Eight <-> Seven(24) P2
# Round 35
# P1 (27) Seven <-> Six(23) P2
# Round 36
# P1 (28) Six <-> Five(22) P2
# Round 37
# P1 (29) Five <-> Nine(21) P2
# Round 38
# P1 (28) Six <-> Nine(22) P2
# Round 39
# P1 (27) Seven <-> Nine(23) P2
# Round 40
# P1 (26) Eight <-> Nine(24) P2
# Round 41
# P1 (25) Ten <-> Nine(25) P2
# Round 42
# P1 (26) Nine <-> Eight(24) P2
# Round 43
# P1 (27) Eight <-> Seven(23) P2
# Round 44
# P1 (28) Seven <-> Six(22) P2
# Round 45
# P1 (29) Six <-> Five(21) P2
# Round 46
# P1 (30) Five <-> Six(20) P2
# Round 47
# P1 (29) Six <-> Six(21) P2
# !!WAR!!
# P1 (28) Seven <-> Five(20) P2
# P1 (27) Eight <-> Nine(19) P2
# P1 (26) Nine <-> King(18) P2
# Round 48
# P1 (25) Ten <-> King(25) P2
# Round 49
# P1 (24) Jack <-> King(26) P2
# Round 50
# P1 (23) Ace <-> King(27) P2
# Round 51
# P1 (24) King <-> Jack(26) P2
# Round 52
# P1 (25) Jack <-> Ten(25) P2
# Round 53
# P1 (26) Ten <-> Nine(24) P2
# Round 54
# P1 (27) Nine <-> Five(23) P2
# Round 55
# P1 (28) Five <-> Six(22) P2
# Round 56
# P1 (27) Nine <-> Six(23) P2
# Round 57
# P1 (28) Six <-> Five(22) P2
# Round 58
# P1 (29) Five <-> Nine(21) P2
# Round 59
# P1 (28) Six <-> Nine(22) P2
# Round 60
# P1 (27) Nine <-> Nine(23) P2
# !!WAR!!
# P1 (26) Ten <-> Six(22) P2
# P1 (25) Jack <-> Five(21) P2
# P1 (24) King <-> Eight(20) P2
# Round 61
# P1 (31) Eight <-> Seven(19) P2
# Round 62
# P1 (32) Seven <-> Six(18) P2
# Round 63
# P1 (33) Six <-> Five(17) P2
# Round 64
# P1 (34) Five <-> Four(16) P2
# Round 65
# P1 (35) Four <-> Jack(15) P2
# Round 66
# P1 (34) Five <-> Jack(16) P2
# Round 67
# P1 (33) Six <-> Jack(17) P2
# Round 68
# P1 (32) Seven <-> Jack(18) P2
# Round 69
# P1 (31) Eight <-> Jack(19) P2
# Round 70
# P1 (30) Five <-> Jack(20) P2
# Round 71
# P1 (29) Six <-> Jack(21) P2
# Round 72
# P1 (28) Nine <-> Jack(22) P2
# Round 73
# P1 (27) King <-> Jack(23) P2
# Round 74
# P1 (28) Jack <-> Nine(22) P2
# Round 75
# P1 (29) Nine <-> Six(21) P2
# Round 76
# P1 (30) Six <-> Five(20) P2
# Round 77
# P1 (31) Five <-> Eight(19) P2
# Round 78
# P1 (30) Six <-> Eight(20) P2
# Round 79
# P1 (29) Nine <-> Eight(21) P2
# Round 80
# P1 (30) Eight <-> Six(20) P2
# Round 81
# P1 (31) Six <-> Five(19) P2
# Round 82
# P1 (32) Five <-> Seven(18) P2
# Round 83
# P1 (31) Six <-> Seven(19) P2
# Round 84
# P1 (30) Eight <-> Seven(20) P2
# Round 85
# P1 (31) Seven <-> Six(19) P2
# Round 86
# P1 (32) Six <-> Five(18) P2
# Round 87
# P1 (33) Five <-> Six(17) P2
# Round 88
# P1 (32) Six <-> Six(18) P2
# !!WAR!!
# P1 (31) Seven <-> Five(17) P2
# P1 (30) Eight <-> Five(16) P2
# P1 (29) Nine <-> Four(15) P2
# Round 89
# P1 (36) Four <-> Six(14) P2
# Round 90
# P1 (35) Five <-> Six(15) P2
# Round 91
# P1 (34) Five <-> Six(16) P2
# Round 92
# P1 (33) Six <-> Six(17) P2
# !!WAR!!
# P1 (32) Nine <-> Five(16) P2
# P1 (31) Eight <-> Five(15) P2
# P1 (30) Seven <-> Four(14) P2
# Round 93
# P1 (37) Four <-> Four(13) P2
# !!WAR!!
# P1 (36) Five <-> Four(12) P2
# P1 (35) Five <-> Seven(11) P2
# P1 (34) Six <-> Two(10) P2
# Round 94
# P1 (41) Two <-> Ace(9) P2
# Round 95
# P1 (40) Seven <-> Ace(10) P2
# Round 96
# P1 (39) Four <-> Ace(11) P2
# Round 97
# P1 (38) Four <-> Ace(12) P2
# Round 98
# P1 (37) Six <-> Ace(13) P2
# Round 99
# P1 (36) Five <-> Ace(14) P2
# Round 100
# P1 (35) Five <-> Ace(15) P2
# Round 101
# P1 (34) Four <-> Ace(16) P2
# Round 102
# P1 (33) Seven <-> Ace(17) P2
# Round 103
# P1 (32) Eight <-> Ace(18) P2
# Round 104
# P1 (31) Nine <-> Ace(19) P2
# Round 105
# P1 (30) Six <-> Ace(20) P2
# Round 106
# P1 (29) Six <-> Ace(21) P2
# Round 107
# P1 (28) Jack <-> Ace(22) P2
# Round 108
# P1 (27) King <-> Ace(23) P2
# Round 109
# P1 (26) Jack <-> Ace(24) P2
# Round 110
# P1 (25) Ten <-> Ace(25) P2
# Round 111
# P1 (24) Nine <-> Ace(26) P2
# Round 112
# P1 (23) Ace <-> Ace(27) P2
# !!WAR!!
# P1 (22) Jack <-> Nine(26) P2
# P1 (21) Queen <-> Ten(25) P2
# P1 (20) Five <-> Jack(24) P2
# Round 113
# P1 (19) Ace <-> Jack(31) P2
# Round 114
# P1 (20) Jack <-> Ten(30) P2
# Round 115
# P1 (21) Ten <-> Nine(29) P2
# Round 116
# P1 (22) Nine <-> Ace(28) P2
# Round 117
# P1 (21) Ten <-> Ace(29) P2
# Round 118
# P1 (20) Jack <-> Ace(30) P2
# Round 119
# P1 (19) Ace <-> Ace(31) P2
# !!WAR!!
# P1 (18) Queen <-> Jack(30) P2
# P1 (17) Ace <-> Ten(29) P2
# P1 (16) Nine <-> Nine(28) P2
# !!WAR!!
# P1 (15) Seven <-> Five(27) P2
# P1 (14) Ten <-> Queen(26) P2
# P1 (13) Queen <-> Jack(25) P2
# Round 120
# P1 (26) Jack <-> Ace(24) P2
# Round 121
# P1 (25) Queen <-> Ace(25) P2
# Round 122
# P1 (24) Five <-> Ace(26) P2
# Round 123
# P1 (23) Nine <-> Ace(27) P2
# Round 124
# P1 (22) Ten <-> Ace(28) P2
# Round 125
# P1 (21) Jack <-> Ace(29) P2
# Round 126
# P1 (20) Ace <-> Ace(30) P2
# !!WAR!!
# P1 (19) Queen <-> Jack(29) P2
# P1 (18) Ten <-> Ten(28) P2
# P1 (17) Seven <-> Nine(27) P2
# Round 127
# P1 (16) Nine <-> Nine(34) P2
# !!WAR!!
# P1 (15) Ace <-> Ten(33) P2
# P1 (14) Queen <-> Jack(32) P2
# P1 (13) Ace <-> Ace(31) P2
# !!WAR!!
# P1 (12) Two <-> Seven(30) P2
# P1 (11) Four <-> Ten(29) P2
# P1 (10) Nine <-> Queen(28) P2
# Round 128
# P1 (9) Ten <-> Queen(41) P2
# Round 129
# P1 (8) Three <-> Queen(42) P2
# Round 130
# P1 (7) Ten <-> Queen(43) P2
# Round 131
# P1 (6) Eight <-> Queen(44) P2
# Round 132
# P1 (5) Five <-> Queen(45) P2
# Round 133
# P1 (4) Queen <-> Queen(46) P2
# !!WAR!!
# P1 (3) Jack <-> Five(45) P2
# P1 (2) Six <-> Eight(44) P2
# P1 (1) Eight <-> Ten(43) P2
# Round 134
# P1 (0) Eight <-> Ten(50) P2
# Round 135
# Player Two Wins!!
